# %%
pip install --user --upgrade pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import json  
import pandas as pd  
from pandas import json_normalize  
import requests
from tabulate import tabulate
from sklearn.cluster import KMeans
import random
import numpy as np
import pandas as pd
import folium
import warnings
warnings.filterwarnings('ignore')
import os
os.environ.keys()
# Out:
# KeysView(environ({'ALLUSERSPROFILE': 'C:\\ProgramData', 'APPDATA': 'C:\\Users\\Harnoor Kaur\\AppData\\Roaming', 'CHOCOLATEYINSTALL': 'C:\\ProgramData\\chocolatey', 'CHOCOLATEYLASTPATHUPDATE': '133489224449424488', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'DESKTOP-41C67TF', 'COMSPEC': 'C:\\windows\\system32\\cmd.exe', 'CONDA_DEFAULT_ENV': 'base', 'CONDA_EXE': 'C:\\Users\\Harnoor Kaur\\anaconda3\\Scripts\\conda.exe', 'CONDA_PROMPT_MODIFIER': '(base) ', 'CONDA_PYTHON_EXE': 'C:\\Users\\Harnoor Kaur\\anaconda3\\python.exe', 'CONDA_SHLVL': '1', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'EFC_11108': '1', 'HOMEDRIVE': 'C:', 'HOMEPATH': '\\Users\\Harnoor Kaur', 'IGCCSVC_DB': '...', 'INTELLIJ IDEA COMMUNITY EDITION': 'C:\\Users\\Harnoor Kaur\\IntelliJ IDEA Community Edition 2023.3.2\\bin;', 'LOCALAPPDATA': 'C:\\Users\\Har
# ...

# %%
url = 'https://discover.search.hereapi.com/v1/discover?in=circle:30.516459,76.659210;r=25000&q=apartment&apiKey=uGsvkD8J0F0BVNil7uTgV--zrx6XgSAL_OtzyV5AX4g'
data = requests.get(url).json()
d=json_normalize(data['items'])
d.to_csv('api-data/apartment.csv')
d
# Out:
#                title                                                 id  \
# 0           Homeland  here:pds:place:356ttqw9-8a12b0db0b814d3dbce2f6...
# 1    Sunrise Complex  here:pds:place:356ttqwk-dd34da153de3e8d9329a5f...
# 2  Motiaz Royal Citi  here:pds:place:356ttqw7-8fae1ca1f4bb4340a7e966...
# 3  World High Street  here:pds:place:356ttqw8-33a2bab5fc18c79c9e8595...
# 4       Golden Homes  here:pds:place:356ttqwb-eb91361cab7cbcedc18c6b...
# 5     Gillco Heights  here:pds:place:356ttqwb-c7ab311bbd1e409fa36cd0...
#
#   language                                     ontologyId resultType  \
# 0       en  here:cm:ontology:apartment_rental_flat_rental      place
# 1    en-GB  here:cm:ontology:apartment_rental_flat_rental      place
# 2    en-GB  here:cm:ontology:apartment_rental_flat_rental      place
# 3       en  here:cm:ontology:apartment_rental_flat_rental      place
# 4    en-GB  here:cm:ontology:apartment_rental_flat_rental      place
# ...

# %%
#Cleaning API data
d2=d[['title','address.label','distance','access','position.lat','position.lng','address.postalCode','id']]
d2.to_csv('api-data/cleaned_apartment.csv')
d2
# Out:
#                title                                      address.label  \
# 0           Homeland          Homeland, Sector 70, Mohali 160071, India
# 1    Sunrise Complex  Sunrise Complex, Sunrise Complex, Zirakpur 140...
# 2  Motiaz Royal Citi  Motiaz Royal Citi, Vishranti City, Vill Ghazip...
# 3  World High Street  World High Street, Sector 115, Mohali 140301, ...
# 4       Golden Homes  Golden Homes, Kharar Landran Road, Sector 115,...
# 5     Gillco Heights  Gillco Heights, Gillco Towers, Kharar 140301, ...
#
#    distance                                access  position.lat  position.lng  \
# 0     20173  [{'lat': 30.69235, 'lng': 76.71079}]      30.69236      76.71081
# 1     20347  [{'lat': 30.64018, 'lng': 76.81562}]      30.64036      76.81561
# 2     20668  [{'lat': 30.63332, 'lng': 76.82739}]      30.63332      76.82709
# 3     22309  [{'lat': 30.71703, 'lng': 76.65341}]      30.71703      76.65357
# ...

# %%
search_query = 'gym' #Search for any gyms
url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uGsvkD8J0F0BVNil7uTgV--zrx6XgSAL_OtzyV5AX4g'.format(latitude, longitude, radius, search_query)
results = requests.get(url).json()
venues=json_normalize(results['items'])
GymList.append(venues['title'].count())
venues
# Out:
#                     title                                                 id  \
# 0     Rajesh Fitness Club  here:pds:place:356ttqwb-804a54b0d9b7486a8af4c1...
# 1        The Physique Gym  here:pds:place:356d408k-a70896701c4705619ec09e...
# 2  Adam & Eve Fitness Gym  here:pds:place:356jx7ps-50752f1fc6f708708003ec...
#
#   language                            ontologyId resultType  \
# 0    en-GB  here:cm:ontology:fitness_health_club      place
# 1    en-GB  here:cm:ontology:fitness_health_club      place
# 2    en-GB  here:cm:ontology:fitness_health_club      place
#
#                                  access  distance  \
# 0  [{'lat': 30.74386, 'lng': 76.64938}]       741
# 1  [{'lat': 30.74301, 'lng': 76.65588}]       880
# 2  [{'lat': 30.74463, 'lng': 76.64436}]       940
#
#                                           categories  \
# 0  [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# 1  [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# ...

# %%
# Counting no. of cafes, department stores and gyms near apartments near thapar
df_final=d2[['position.lat','position.lng']]

CafeList=[]
ResList=[]
GymList=[]
latitudes = list(d2['position.lat'])
longitudes = list( d2['position.lng'])
for lat, lng in zip(latitudes, longitudes):    
    radius = '1000' #Set the radius to 1000 metres
    latitude=lat
    longitude=lng
    
    search_query = 'cafe' #Search for any cafes
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uGsvkD8J0F0BVNil7uTgV--zrx6XgSAL_OtzyV5AX4g'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=json_normalize(results['items'])
    CafeList.append(venues['title'].count())
	
    search_query = 'gym' #Search for any gyms
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uGsvkD8J0F0BVNil7uTgV--zrx6XgSAL_OtzyV5AX4g'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    # venues=json_normalize(results['items'])
    venues = json_normalize(results['items'] if 'items' in results else [])  # Handle empty results
    if len(venues) > 0:  # Check if there are any venues before accessing columns
        GymList.append(venues['title'].count())
    else:
        GymList.append(0)

    search_query = 'restaurents' #search for supermarkets
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uGsvkD8J0F0BVNil7uTgV--zrx6XgSAL_OtzyV5AX4g'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=json_normalize(results['items'])
    ResList.append(venues['title'].count())

df_final['Cafes'] = CafeList
df_final['Restaurents'] = ResList
df_final['Gyms'] = GymList

df_final
# Out:
#    position.lat  position.lng  Cafes  Restaurents  Gyms
# 0      30.69236      76.71081      2           20    12
# 1      30.64036      76.81561      2           20    12
# 2      30.63332      76.82709      3           20     3
# 3      30.71703      76.65357      1           20     0
# 4      30.72579      76.65119      1           20     1
# 5      30.73728      76.64937      2           20     3

# %%
#Run K-means clustering on dataframe
kclusters = 3

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_final)
df_final['Cluster']=kmeans.labels_
df_final['Cluster']=df_final['Cluster'].apply(str)
df_final
# Out:
#    position.lat  position.lng  Cafes  Restaurents  Gyms Cluster
# 0      30.69236      76.71081      2           20    12       1
# 1      30.64036      76.81561      2           20    12       1
# 2      30.63332      76.82709      3           20     3       2
# 3      30.71703      76.65357      1           20     0       0
# 4      30.72579      76.65119      1           20     1       0
# 5      30.73728      76.64937      2           20     3       2

# %%
#Plotting clustered locations on map using Folium

#define coordinates of the college
map_bom=folium.Map(location=[30.516459, 76.659210],zoom_start=12)

# instantiate a feature group for the incidents in the dataframe
locations = folium.map.FeatureGroup()

# set color scheme for the clusters
def color_producer(cluster):
    if cluster=='0':
        return 'green'
    elif cluster=='1':
        return 'orange'
    else:
        return 'red'

latitudes = list(df_final['position.lat'])
longitudes = list(df_final['position.lng'])
labels = list(df_final['Cluster'])
names=list(d2['title'])
for lat, lng, label,names in zip(latitudes, longitudes, labels,names):
    folium.CircleMarker(
            [lat,lng],
            fill=True,
            fill_opacity=1,
            popup=folium.Popup(names, max_width = 300),
            radius=5,
            color=color_producer(label)
        ).add_to(map_bom)

# add locations to map
map_bom.add_child(locations)
folium.Marker([30.516459, 76.659210],popup='Chitkara University').add_to(map_bom)

# %%
#saving the map 
map_bom.save("ChitkaraUniversity.html")
